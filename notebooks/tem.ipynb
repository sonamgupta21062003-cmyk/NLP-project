# %%
import os
import sys
from pathlib import Path

# %%
project_root = Path(os.getcwd()).parent
backend_path = str(project_root / "backend")

# 2. इसे Python की सर्च लिस्ट (sys.path) में जोड़ें
if backend_path not in sys.path:
    sys.path.append(backend_path)

# 3. अब आपका इंपोर्ट बिना किसी एरर के काम करेगा!
from app.core.config import settings

# प्रिंट करके चेक करें कि क्या सेटिंग्स लोड हो रही हैं
print("Model Name:", settings.MODEL_NAME)
print("Debug Status:", settings.DEBUG)
print("Database URL:", settings.DATABASE_URL)
# Out:
# Model Name: distilbert-base-uncased
# Debug Status: False
# Database URL: sqlite:///customer_support.db

# %%
import sys

sys.path.append("../backend")

# %%
from app.ai.intent import (
    predict_intent_svm,
    predict_intent_bert
)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
predict_intent_svm(
    "I want to cancel my order"
)
# Out:
# 'cancel_order'

# %%
predict_intent_bert("Where is my package?")
# Out:
# {'intent': 'delivery_period', 'confidence': 0.6817782521247864}

# %%
predict_intent_bert("I forgot my password")
# Out:
# {'intent': 'recover_password', 'confidence': 0.9992769360542297}

# %%
predict_intent_bert("How do I get my invoice?")
# Out:
# {'intent': 'get_invoice', 'confidence': 0.9939929842948914}

# %%
"""
Confidence scoring utilities.
"""

HIGH_CONFIDENCE = 0.90
MEDIUM_CONFIDENCE = 0.75


def get_confidence_level(score: float) -> str:

    if score >= HIGH_CONFIDENCE:
        return "HIGH"

    elif score >= MEDIUM_CONFIDENCE:
        return "MEDIUM"

    return "LOW"


def should_escalate(score: float) -> bool:

    return score < MEDIUM_CONFIDENCE

# %%
import app.ai.confidence as confidence

print(dir(confidence))
# Out:
# ['HIGH_CONFIDENCE', 'MEDIUM_CONFIDENCE', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'get_confidence_level', 'should_escalate']

# %%
import app.ai.confidence as confidence

print(confidence.__file__)
# Out:
# c:\Users\Dell\Desktop\nlp project\backend\app\ai\confidence.py

# %%
import sys

sys.path.append("../backend")

# %%
import app.ai.confidence as confidence

print(confidence.__file__)
print(dir(confidence))
# Out:
# c:\Users\Dell\Desktop\nlp project\backend\app\ai\confidence.py
# ['HIGH_CONFIDENCE', 'MEDIUM_CONFIDENCE', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'get_confidence_level', 'should_escalate']

# %%
with open("../backend/app/ai/confidence.py", "r", encoding="utf-8") as f:
    print(f.read())
# Out:
# """
# Confidence scoring utilities.
#
# This module decides whether the intent prediction
# is reliable enough to continue with the AI pipeline.
# """
#
#
# HIGH_CONFIDENCE = 0.90
# MEDIUM_CONFIDENCE = 0.75
#
#
# def get_confidence_level(score: float) -> str:
#     """
#     Convert a confidence score into a readable level.
#     """
#
#     if score >= HIGH_CONFIDENCE:
#         return "HIGH"
#
#     elif score >= MEDIUM_CONFIDENCE:
#         return "MEDIUM"
#
#     return "LOW"
#
#
# def should_escalate(score: float) -> bool:
#     """
#     Return True if the prediction is too uncertain.
#     """
#
#     return score < MEDIUM_CONFIDENCE

# %%
from app.ai.confidence import (
    get_confidence_level,
    should_escalate
)

print(get_confidence_level(0.98))
print(get_confidence_level(0.82))
print(get_confidence_level(0.60))

print(should_escalate(0.98))
print(should_escalate(0.60))
# Out:
# HIGH
# MEDIUM
# LOW
# False
# True

# %%
from app.utils.preprocessing import clean_text

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Dell\Desktop\nlp project\notebooks

# %%
import sys
print(sys.path)
# Out:
# ['c:\\Users\\Dell\\Desktop\\nlp project\\backend', 'c:\\Users\\Dell\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'c:\\Users\\Dell\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'c:\\Users\\Dell\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'c:\\Users\\Dell\\AppData\\Local\\Programs\\Python\\Python312', '', 'c:\\Users\\Dell\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages', 'c:\\Users\\Dell\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\win32', 'c:\\Users\\Dell\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\Dell\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pythonwin']

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
backend_path = project_root / "backend"

if str(backend_path) not in sys.path:
    sys.path.insert(0, str(backend_path))

print(backend_path)
# Out:
# c:\Users\Dell\Desktop\nlp project\backend

# %%
from app.utils.preprocessing import clean_text

# %%
from app.ai.intent import predict_intent_bert
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
predict_intent_bert("      CANCEL MY ORDER!!!!!!")
# Out:
# {'intent': 'cancel_order', 'confidence': 0.9979162812232971}

# %%
predict_intent_bert("   WHERE      IS MY PACKAGE????")
# Out:
# {'intent': 'delivery_period', 'confidence': 0.6848454475402832}

# %%
pip install nltk
# Out:
# ...
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# ...
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from app.ai.sentiment import predict_sentiment
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...

# %%
predict_sentiment(
    "I love your service."
)
# Out:
# {'sentiment': 'Positive',
#  'scores': {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.6369}}

# %%
predict_sentiment(
    "I am extremely angry with your company."
)
# Out:
# {'sentiment': 'Negative',
#  'scores': {'neg': 0.418, 'neu': 0.582, 'pos': 0.0, 'compound': -0.5563}}

# %%
predict_sentiment(
    "Where is my order?"
)
# Out:
# {'sentiment': 'Neutral',
#  'scores': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}}

# %%
from app.core.logger import get_logger

logger = get_logger(__name__)

logger.info("Logger is working!")c
logger.warning("This is a warning.")
logger.error("This is a test error.")
# Out:
# 2026-06-29 06:19:47,988 | INFO | __main__ | Logger is working!
# 2026-06-29 06:19:47,988 | WARNING | __main__ | This is a warning.
# 2026-06-29 06:19:47,988 | ERROR | __main__ | This is a test error.

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show sqlalchemy
# Out:
# Name: SQLAlchemy
# Version: 2.0.51
# Summary: Database Abstraction Library
# Home-page: https://www.sqlalchemy.org
# Author: Mike Bayer
# Author-email: mike_mp@zzzcomputing.com
# License: MIT
# Location: c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages
# Requires: greenlet, typing-extensions
# Required-by: langchain-classic, langchain-community
# Note: you may need to restart the kernel to use updated packages.

# %%
from app.database.db import engine

# %%
print(engine)
# Out:
# Engine(sqlite:///customer_support.db)

# %%
from app.database.db import engine
from app.database.models import Base

Base.metadata.create_all(bind=engine)

print("Database Created Successfully!")
# Out:
# Database Created Successfully!

# %%
from sqlalchemy import inspect
from app.database.db import engine

inspector = inspect(engine)

print(inspector.get_table_names())
# Out:
# ['analytics', 'chat_history', 'feedback']

# %% [markdown]
# Type a customer question in the Streamlit UI.
# FastAPI receives it.
# Text is preprocessed.
# DistilBERT predicts the intent.
# Sentiment is detected.
# Confidence is calculated.
# RAG retrieves relevant knowledge.
# The LLM generates a response.
# The conversation is saved to SQLite.
# The answer is displayed in the chat interface.
#
# That gives you a complete, end-to-end AI Customer Support Agent.

# %%
#chat_service.py
from app.database.db import SessionLocal
from app.services.chat_service import process_chat

# %%
db = SessionLocal()

# %%
result = process_chat(
    message="I want to cancel my order",
    db=db
)

result
# Out:
# {'intent': 'cancel_order',
#  'confidence': 0.9991820454597473,
#  'confidence_level': 'HIGH',
#  'escalation': False,
#  'sentiment': 'Negative',
#  'response': "I detected your intent as 'cancel_order'. My confidence is 1.00."}

# %%
result = process_chat(
    message="I am extremely angry. Cancel my order immediately!",
    db=db
)

result
# Out:
# {'intent': 'cancel_order',
#  'confidence': 0.9980424642562866,
#  'confidence_level': 'HIGH',
#  'escalation': False,
#  'sentiment': 'Negative',
#  'response': "I detected your intent as 'cancel_order'. My confidence is 1.00."}

# %%
result = process_chat(
    message="Thank you so much for helping me.",
    db=db
)

result
# Out:
# {'intent': 'contact_human_agent',
#  'confidence': 0.7000032663345337,
#  'confidence_level': 'LOW',
#  'escalation': True,
#  'sentiment': 'Positive',
#  'response': "I detected your intent as 'contact_human_agent'. My confidence is 0.70."}

# %%
# Database test
from app.database.crud import get_chat_history

history = get_chat_history(db)

len(history)
# Out:
# 3

# %%
history[-1].user_message
# Out:
# 'Thank you so much for helping me.'

# %%
history[-1].predicted_intent
# Out:
# 'contact_human_agent'

# %%
history[-1].sentiment
# Out:
# 'Positive'

# %%
history[-1].confidence
# Out:
# 0.7000032663345337

# %%
pip install fastapi uvicorn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
