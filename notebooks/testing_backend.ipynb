# %%
import sys
sys.path.append("../backend")

# %%
from app.ai.intent import predict_intent

# %%
predict_intent(
    "I want to cancel my order"
)
# Out:
# 'cancel_order'

# %%
predict_intent("Where is my package?")
# Out:
# 'delivery_period'

# %%
predict_intent("How do I get my invoice?")
# Out:
# 'get_invoice'

# %%
predict_intent("I forgot my password")
# Out:
# 'recover_password'
